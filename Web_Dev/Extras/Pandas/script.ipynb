# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\sujee\AppData\Roaming\Python\Python314\site-packages (3.0.6)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\sujee\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\sujee\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\sujee\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.4)
# Requirement already satisfied: six>=1.5 in C:\Users\sujee\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.DataFrame([11,22,33], columns=['Col_Name'])

# %%
data = {
    'Name' : ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16, 17, 18, 19],
    'Salary': [90000, 70000,50000,30000]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
print(df.head(1))
# Out:
#      Name  Age  Salary
# 0  Madhav   16   90000

# %%
df.tail(1)
# Out:
#       Name  Age  Salary
# 3  Rishabh   19   30000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns={'Salary': 'Monthly_Salary'})
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
#3. Save and Load data from CSV

df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.to_csv('Test_data.csv')

# %%
df.to_csv('Test_data.csv', index=False) #export data frame

# %%
load_df = pd.read_csv('Test_data.csv') #import data frame
load_df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
#4. Rows & Columns - Selection

# %%
# select column
df[['Name', 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3   Rishabh           30000

# %%
# Select rows
# loc - index name based
df.loc[df.Name=='Madhav']
df.loc[(df.Name=='Madhav') & (df.Monthly_Salary>=50000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[0:2]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000

# %%
# iloc - index value based
# df.iloc[0]
df.iloc[0:2]        #[start:stop:step]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %%
# filter dataframe

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df['Age'] > 15
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: Age, dtype: bool

# %%
df[df['Age'] >= 18]   # getting true value only
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df_age_filter = df[df['Age'] >= 18]

# %%
df_age_filter
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 50000)]
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   18           50000

# %%
df.where(df['Age'] >= 18)
# Out:
#       Name   Age  Monthly_Salary
# 0      NaN   NaN             NaN
# 1      NaN   NaN             NaN
# 2   Lalita  18.0         50000.0
# 3  Rishabh  19.0         30000.0

# %%
df.where(df['Age'] >= 18, other = 'Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            18          50000
# 3       Rishabh            19          30000

# %%
#6. Rows and Columns - Operations (Add, Update, Delete)
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
# add new column
df['Team'] = ['CEO', 'HR', 'CTO', 'DA']
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
df['Bonus'] = df['Monthly_Salary'] * 0.2
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0

# %%
# add new row
df.loc[len(df)] = ['ABC', 21, 21000, 'IT', 2000]
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0

# %%
len(df)
# Out:
# 5

# %%
# update value
df.loc[0, 'Monthly_Salary'] = 95000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           95000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0

# %%
#update value - using column value
df.loc[df.Name == 'Madhav', 'Monthly_Salary'] = 90000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary  Monthly_salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0         90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN             NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN             NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN             NaN
# 4       ABC   21           21000   IT   2000.0      NaN             NaN

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary  Monthly_salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0         90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN             NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN             NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN             NaN
# 4       ABC   21           21000   IT   2000.0      NaN             NaN

# %%
# delete value - row and column values
df.drop(df[df.Name == 'ABC'].index)  #drop row, axis = 0
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary  Monthly_salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0         90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN             NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN             NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN             NaN

# %%
df[df.Name == 'ABC']
# Out:
#   Name  Age  Monthly_Salary Team   Bonus  salary  Monthly_salary
# 4  ABC   21           21000   IT  2000.0     NaN             NaN

# %%
df.drop('salary', axis=1)
# Out:
#        Name  Age  Monthly_Salary Team    Bonus  Monthly_salary
# 0    Madhav   16           90000  CEO  18000.0         90000.0
# 1  Vishakha   17           70000   HR  14000.0             NaN
# 2    Lalita   18           50000  CTO  10000.0             NaN
# 3   Rishabh   19           30000   DA   6000.0             NaN
# 4       ABC   21           21000   IT   2000.0             NaN

# %%
df.drop('Monthly_salary', axis=1)
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN
# 4       ABC   21           21000   IT   2000.0      NaN

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary  Monthly_salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0         90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN             NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN             NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN             NaN
# 4       ABC   21           21000   IT   2000.0      NaN             NaN

# %%
df = df.drop('Monthly_salary', axis=1)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus   salary
# 0    Madhav   16           90000  CEO  18000.0  90000.0
# 1  Vishakha   17           70000   HR  14000.0      NaN
# 2    Lalita   18           50000  CTO  10000.0      NaN
# 3   Rishabh   19           30000   DA   6000.0      NaN
# 4       ABC   21           21000   IT   2000.0      NaN

# %%
df = df.drop('salary', axis=1)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0

# %%
df = df.drop(df[df.Name == 'ABC'].index)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
